# %% [markdown]
# # This is the first attemt for a natural selection simulation
#
#
# ## Frist some literature and tutorial are needed:
#
# ### Simulation
# Here we will collect the literature and relevant infromation to create an natural selection simulation in python. In the end something like this should be created:

# %%
from IPython.display import YouTubeVideo

#Youtube
id ='0ZGbIKd0XrM' #the last digets of the youtube video
YouTubeVideo(id = id, width = 900, hight = 400)

# %% [markdown]
# ### Neuronal Network (or other form of inteligents)
# ### GUI
# ### Website
# ### Etc.

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/0ZGbIKd0XrM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/0ZGbIKd0XrM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
